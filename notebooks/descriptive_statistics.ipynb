# %%
import numpy as np                    # ---> to handle N Dimentional array
import pandas as pd                   # -->  to handle Dataframe ( 2D Lebelled Data )
import matplotlib.pyplot as plt       # -->  For Visaulization
import seaborn as sns                 # -->  For Advanced Visaulization

# %%
house_exnp = pd.read_csv(r"C:\Users\Akash\Downloads\household_dataset.csv")

# %%
house_exnp.head(2)
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0            20795             18198                  1            16599
# 1             5860              3722                  8                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0            248852           Under-Graduate                      3
# 1             66644           Under-Graduate                      1

# %%
house_exnp.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
len(house_exnp.columns)
# Out:
# 7

# %%
house_exnp.info
# Out:
# <bound method DataFrame.info of      Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              20795             18198                  1            16599
# 1               5860              3722                  8                0
# 2              81820             24299                  1            16599
# 3              59886             45585                  8                0
# 4              11265             12921                  4                0
# ..               ...               ...                ...              ...
# 145            85356              5987                  7            16599
# 146            76910             60871                  6                0
# 147            61044             24399                  3                0
# 148            72214             48214                  4            16599
# 149            38827             35986                  5            16599
#
# ...

# %%
house_exnp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           150 non-null    int64
#  1   Mthly_HH_Expense          150 non-null    int64
#  2   No_of_Fly_Members         150 non-null    int64
#  3   Emi_or_Rent_Amt           150 non-null    int64
#  4   Annual_HH_Income          150 non-null    int64
#  5   Highest_Qualified_Member  150 non-null    object
#  6   No_of_Earning_Members     150 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 8.3+ KB

# %%
house_exnp.shape
# Out:
# (150, 7)

# %%
house_exnp.describe()               # Handles ONlY Numeric Values
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count       150.000000        150.000000         150.000000       150.000000
# mean      55066.660000      26302.633333           4.600000      9848.740000
# std       28566.602214      19697.690585           2.345923      8180.937636
# min        5206.000000       2197.000000           1.000000         0.000000
# 25%       29359.500000       8871.500000           2.250000         0.000000
# 50%       58351.000000      22904.500000           5.000000     16599.000000
# 75%       79041.000000      42247.000000           7.000000     16599.000000
# max       99663.000000      73295.000000           8.000000     16599.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      1.500000e+02             150.000000
# mean       6.608247e+05               1.966667
# std        3.427314e+05               0.797788
# min        6.537300e+04               1.000000
# ...

# %%
house_exnp.describe().T
# Out:
#                        count           mean            std      min  \
# Mthly_HH_Income        150.0   55066.660000   28566.602214   5206.0
# Mthly_HH_Expense       150.0   26302.633333   19697.690585   2197.0
# No_of_Fly_Members      150.0       4.600000       2.345923      1.0
# Emi_or_Rent_Amt        150.0    9848.740000    8180.937636      0.0
# Annual_HH_Income       150.0  660824.653333  342731.376138  65373.0
# No_of_Earning_Members  150.0       1.966667       0.797788      1.0
#
#                              25%       50%       75%        max
# Mthly_HH_Income         29359.50   58351.0   79041.0    99663.0
# Mthly_HH_Expense         8871.50   22904.5   42247.0    73295.0
# No_of_Fly_Members           2.25       5.0       7.0        8.0
# Emi_or_Rent_Amt             0.00   16599.0   16599.0    16599.0
# Annual_HH_Income       352726.75  702945.5  946063.5  1193735.0
# No_of_Earning_Members       1.00       2.0       3.0        3.0

# %%
house_exnp.isna()
# Out:
#      Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              False             False              False            False
# 1              False             False              False            False
# 2              False             False              False            False
# 3              False             False              False            False
# 4              False             False              False            False
# ..               ...               ...                ...              ...
# 145            False             False              False            False
# 146            False             False              False            False
# 147            False             False              False            False
# 148            False             False              False            False
# 149            False             False              False            False
#
# ...

# %%
house_exnp.isna().any()           # any means --> is there any null value
# Out:
# Mthly_HH_Income             False
# Mthly_HH_Expense            False
# No_of_Fly_Members           False
# Emi_or_Rent_Amt             False
# Annual_HH_Income            False
# Highest_Qualified_Member    False
# No_of_Earning_Members       False
# dtype: bool

# %%
house_exnp.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
house_exnp['Mthly_HH_Income'].mean()
# Out:
# np.float64(55066.66)

# %%
print(house_exnp['Mthly_HH_Income'].mean())
# Out:
# 55066.66

# %%
print(house_exnp['Mthly_HH_Income'].median())
# Out:
# 58351.0

# %%
print(house_exnp['Mthly_HH_Income'].mode())
# Out:
# 0       5206
# 1       5769
# 2       5860
# 3       6016
# 4       7568
#        ...
# 145    96387
# 146    97067
# 147    97093
# 148    98016
# 149    99663
# Name: Mthly_HH_Income, Length: 150, dtype: int64

# %%
print(house_exnp['Mthly_HH_Income'].mode()[0])
# Out:
# 5206

# %%
mnth_exp_tmp = pd.crosstab(index = house_exnp['Mthly_HH_Expense'], columns = "count")

mnth_exp_tmp.reset_index(inplace = True)

mnth_exp_tmp[mnth_exp_tmp['count'] == house_exnp.Mthly_HH_Expense.value_counts().max()]
# Out:
# col_0  Mthly_HH_Expense  count
# 39                 9392      2

# %%
house_exnp['Highest_Qualified_Member'].value_counts().plot()
# Out:
# <Axes: xlabel='Highest_Qualified_Member'>

# %%
house_exnp['Highest_Qualified_Member'].value_counts().plot(kind = 'bar')      # Univariate Graph
# Out:
# <Axes: xlabel='Highest_Qualified_Member'>

# %%
house_exnp.plot(x = 'Mthly_HH_Income', y =  'Mthly_HH_Expense')           # Bivariate,  This is Kutoise type not Skewness
# Out:
# <Axes: xlabel='Mthly_HH_Income'>

# %%
# INTERVIEW QUESTION

# Can you find 50% Quartine of the data ( or specific column )

IQR = house_exnp['Mthly_HH_Income'].quantile(0.75) - house_exnp['Mthly_HH_Income'].quantile(0.25)
print(IQR)
# Out:
# 49681.5

# %%
IQR = house_exnp['Mthly_HH_Income'].quantile(0.25)
print(IQR)
# Out:
# 29359.5

# %%
IQR = house_exnp['Mthly_HH_Income'].quantile(0.50)
print(IQR)
# Out:
# 58351.0

# %%
IQR = house_exnp['Mthly_HH_Income'].quantile(0.75)
print(IQR)
# Out:
# 79041.0

# %%
IQR = house_exnp['Mthly_HH_Income'].quantile(1)
print(IQR)
# Out:
# 99663.0

# %%
house_exnp['Mthly_HH_Income'].var()              # Variance
# Out:
# 816050762.0514097

# %%
house_exnp['Mthly_HH_Income'].std()             # Standard Deviation
# Out:
# 28566.602213973747

# %%
coef = house_exnp['Mthly_HH_Income'].std() / house_exnp['Mthly_HH_Income'].mean()           # Coefficient
print(coef)
# Out:
# 0.5187640255278556
